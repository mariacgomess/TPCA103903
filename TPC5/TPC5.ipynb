# %% [markdown]
# ### TPC5: Aplicação para Gerir um Cinema
#
# Suponha que está a desenvolver uma aplicacão para gestão de um conjunto de salas de cinema de um centro comercial.
# Nesse centro comercial existem algumas salas de cinema (que poderão estar a exibir filmes ou não), cada sala tem uma determinada
# lotação, uma lista com a referência dos bilhetes vendidos (lugares ocupados; cada lugar é identificado por um número inteiro), e cada sala tem um filme associado.
#
# Considera a seguinte sugestão para o modelo dos cinemas:
# ```
# Cinema = [Sala]
# Sala = [nlugares, Vendidos, filme]
# nlugares = Int
# filme = String
# Vendidos = [Int]
# ```
#
# Que poderá ser usado num programa da seguinte forma:
# ```
# sala1 = (150, [], "Twilight")
# sala2 = (200, [], "Hannibal")
# cinema1 = []
# ...
# cinema1 = inserirSala(cinema1,sala1)
# cinema1 = inserirSala(cinema1,sala2)
# ...
# listar(cinema1)
# ...
#
# if(disponivel(cinema1, "Twilight", 17 )):
#   cinema1 = vendebilhete(cinema1, "Twilight", 17 )
# ...
# listardisponibilidades(cinema1)
# ...
# ```
#
# Especifique as funções utilizadas no exemplo:
#
# 1. `listar( cinema )` - que lista no monitor todos os filmes que estão em exibição nas salas do cinema passado como argumento;
# 2. `disponivel( cinema, filme, lugar )` - que dá como resultado **False** se o lugar lugar já estiver ocupado na sala onde o filme está a ser exibido e dará como resultado **True** se o inverso acontecer;
# 3. `vendebilhete( cinema, filme, lugar )` - que dá como resultado um novo cinema resultante de acrescentar o lugar à lista dos lugares ocupados, na sala onde está a ser exibido o filme;
# 4. `listardisponibilidades( cinema )` - que, para um dado cinema, lista no monitor para cada sala, o filme que está a ser exibido e o total de lugares disponíveis nessa sala (número de lugares na sala menos o número de lugares ocupados);
# 5. `inserirSala( cinema, sala )` - que acrescenta uma sala nova a um cinema (devendo verificar se a sala já existe);
# 6. Acrescente todas as outras funcionalidades que achar necessárias;
# 7. À semelhança do exercício 3, construa uma aplicação com um menu de interface para as operações.

# %%
sala1=[150, [], "Twilight"]
sala2=[200, [], "Hannibal"]
cinema=[sala1,sala2]


def listar(cinema):
    print ("Os filmes em exibição são")
    for s in cinema:
        print(s[2])
        

def disponível(cinema, filme, lugar):
    for s in cinema:
        if filme==s[2]:
            if lugar not in s[1]:
                v= True
            else: 
                v= False
    return v




def vendobilhete (cinema, filme, lugar):
        if disponível(cinema, filme, lugar):
            for s in cinema:
                if filme==s[2]:
                    s[1].append(lugar)
            return cinema
        else:("Lugar",lugar,"indisponível.Por favor escolha outro lugar.")
        

def listardisponibilidade(cinema):
    for s in cinema:
        nlugares= s[0] - len(s[1])
        print ("Na sala com o filme",s[2],"em exibição, estão disponiveis",nlugares,"lugares")

def insrirSala (cinema, sala):
    if sala not in cinema:
            cinema.append(sala)
    return cinema


print("Menu \n (1) Filmes em exibição \n (2) Disponibilidade das Salas \n (3) Disponibilidade de lugares \n (4) Vender Bilhete \n (5) Acrescentar sala \n (0) Sair ")
op=(int(input("Que opção deseja?")))
while op != 0:
    if op == 1:
        listar(cinema)
        op=(int(input("Que opção deseja?")))
    if op == 2:
        listardisponibilidade(cinema)
        op=(int(input("Que opção deseja?")))
    if op==3:
        filme=str(input("Que filme que consultar?"))
        lugar=int(input("Que lugar quer consultar?"))
        disponível(cinema, filme, lugar)
        if disponível(cinema,filme,lugar):
            print("lugar",lugar,"disponível")
        else:
            print("Lugar",lugar,"ocupado")
        op=(int(input("Que opção deseja?")))
    if op == 4:
        filme=str(input("Que Filme deseja ver?"))
        lugar=int(input("Em que lugar?"))
        vendobilhete(cinema,filme,lugar)
        print("O bilhete para o filme",filme,"no lugar",lugar,"foi vendido")

        op=(int(input("Que opção deseja?")))
    if op == 5:
        filme=str(input("Que filme vai exibir?"))
        nlugares=int(input("Quantos lugares vai ter?"))
        sala=[nlugares, [],filme]
        insrirSala ( cinema, sala)
        print("A sala com o filme", filme,"com",nlugares,"lugares, foi adicionada!")

        op=(int(input("Que opção deseja?")))
print("O programa foi encerrado!Adeus!")
# Out:
# Menu
#  (1) Filmes em exibição
#  (2) Disponibilidade das Salas
#  (3) Disponibilidade de lugares
#  (4) Vender Bilhete
#  (5) Acrescentar sala
#  (0) Sair
# Os filmes em exibição são
# Twilight
# Hannibal
# Na sala com o filme Twilight em exibição, estão disponiveis 150 lugares
# Na sala com o filme Hannibal em exibição, estão disponiveis 200 lugares
# A sala com o filme Harry Potter com 130 lugares, foi adicionada!
# Na sala com o filme Twilight em exibição, estão disponiveis 150 lugares
# Na sala com o filme Hannibal em exibição, estão disponiveis 200 lugares
# Na sala com o filme Harry Potter em exibição, estão disponiveis 130 lugares
# lugar 35 disponível
# O bilhete para o filme Twilight no lugar 35 foi vendido
# Lugar 35 ocupado
# Na sala com o filme Twilight em exibição, estão disponiveis 149 lugares
# Na sala com o filme Hannibal em exibição, estão disponiveis 200 lugares
# Na sala com o filme Harry Potter em exibição, estão disponiveis 130 lugares
# O programa foi encerrado!Adeus!
