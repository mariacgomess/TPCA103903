# %% [markdown]
# ### TPC7: Construir uma aplicação para manipular polinómios
#
# Depois da aula da semana passada, já tens algumas funções desenvolvidas que te irão ajudar a construir a aplicação que se descreve a seguir.
#
# * Aquecimento: Instancia os seguintes exemplos num ficheiro de texto com o formato definido na última aula
#     - `x^7 - 3.7x^4 + 5x^3 - 88`
#     - `2x^2 + 17`
#     - `7x^4 + 6x^3 - x^2 + 43`
#     - `x^4`
#     - `x^2`
#     - `x^3`
#
# * Desenvolve as seguintes funcionalidades que não foram trabalhadas na aula:
#     1. Define uma função que dado um polinómio calcula a sua derivada;
#     2. Define uma função que recebe dois polinómios `p1` e `p2` e calcula um novo polinómio correspondente à soma de `p1` e `p2`;
#     3. Define uma função que recebe um polinómio e o desenha num gráfico.
#
# * Num ficheiro Python, cria uma aplicação para manipular polinómios com as seguintes operações:
#     1. Criar um polinómio interativamente;
#     2. Ler uma lista de polinómios de um ficheiro;
#     3. Listar polinómios: mostra numa tabela os polinómios carregados em memória, adicionando um número de ordem a cada um;
#     4. Calcular o valor de um polinómio num ponto (usa o número de ordem para referenciar o polinómio);
#     5. Listar polinómios com grau: à listagem anterior, acrescenta mais uma coluna com o grau;
#     6. Maior grau: mostra o polinómio de maior grau e indica o seu número de ordem;
#     7. Derivada: mostra uma tabela com os polinómios e as respetivas derivadas;
#     8. Somar dois polinómios: indicando os seus números de ordem;
#     9. Gerar um gráfico para o polinómio;
#     10. Gravar num ficheiro os polinómios em memória;
#     0. Sair da aplicação

# %%
p1=[(1,7),(-3.7, 4),(5, 3), (-88,0)]
p2=[(2,2), (17,0)]
p3=[(7,4),(6,3),(-1,2),(43,0)]
p4=[(1,4)]
p5=[(1,2)]
p6=[(1,3)]

# %%
def ficheiro(lista,nome):
    file=open(nome, "w")
    for p in listap:
        for polinómio in p:
            c, g = polinómio
            file.write(str(c)+","+str(g)+";")
        file.write("\n")
  
    file.close()
listap=[p1,p2,p3,p4,p5,p6]
ficheiro (listap,"polinómio.txt")

# %%
def derivada(polinómio):
    registo=[]
    for c,g in polinómio:
        if g!=0:
            p=(c/g,g-1)
            registo.append(p)
            p=0
        else:
            p=(0,0)
            registo.append(p)
            p=0
            
    print (registo)
    
derivada(p1)
derivada(p2)
derivada(p3)
derivada(p4)
derivada(p5)
derivada(p6)
#p1=[(1,7),(-3.7, 4),(5, 3), (-88,0)]
#p2=[(2,2), (17,0)]
#p3=[(7,4),(6,3),(-1,2),(43,0)]
#p4=[(1,4)]
#p5=[(1,2)]
#p6=[(1,3)]
# Out:
# [(0.14285714285714285, 6), (-0.925, 3), (1.6666666666666667, 2), (0, 0)]
# [(1.0, 1), (0, 0)]
# [(1.75, 3), (2.0, 2), (-0.5, 1), (0, 0)]
# [(0.25, 3)]
# [(0.5, 1)]
# [(0.3333333333333333, 2)]

# %%
def soma(p1,p2):
    registo=[]
    #polinómio(c,g)
    #p1-i;p2-j
    i=0
    j=0
    while i<len(p1) and j<len(p2):
        (c1,g1)=p1[i]        
        (c2,g2)=p2[j]
        if g1==g2:
            p=(c1+c2,g1)
            registo.append(p)
            i=i+1
            j=j+1
        elif g1>g2:
            registo.append((c1,g1)) 
            i=i+1
        else:
            registo.append((c2,g2))
            j=j+1

    while i<len(p1):
        (c1,g1)=p1[i]        
        registo.append((c1,g1)) 
        i=i+1

    while j<len(p2):
        (c2,g2)=p2[j]
        registo.append((c2,g2))
        j=j+1

    print (registo)
soma(p2,p3)
# Out:
# [(7, 4), (6, 3), (1, 2), (60, 0)]

# %%
import matplotlib.pyplot as plt

def potência(a,b):
    res=1
    while b>0:
        res= a*res
        b=b-1
    return res

def calcula(p,x):
    i=0
    resu=0
    while i<len(p):
        (c1,g1)=p[i]
        resu=resu+(c1*(potência(x,g1)))
        i=i+1
    return resu

def gráfico(p):
    valx=[]
    valy=[]
    x=0
    while x<=10:
        valx.append(x)
        y=calcula(p,x)
        valy.append(y)
        x=x+1

    plt.plot(valx, valy, color = "green")
    plt.xlabel("abssissa")
    plt.ylabel("ordenada")
    plt.title("polinómio")
    plt.show()

print(gráfico(p2))
# Out:
# None

# %%
def criapolinómio():
    pol=[]
    g=(int(input("De que grau?")))
    g1=0
    while g1<=g:
        c=(int(input("Inseriri coeficiente para grau"+str(g1))))
        if c!=0:
            pol.append((c,g1))
        g1=g1+1
    print(pol)
    listap.append(pol)
    ficheiro (listap,"polinómio.txt")

def lerlista(nome):
    lista=open(nome,"r")
    linhas=lista.readlines()
    ficheiro=[]
    for linha in linhas:
        pol=[]
        termo=linha.split(";")
        termo.remove("\n")
        for t in termo:
            mon=t.split(",")
            mono=(float(mon[0]),int(mon[1]))
            pol.append(mono)
        ficheiro.append(pol)
    lista.close()
    return ficheiro

def listar(nome):
    print("Ordem------------Polinómio")
    lista=open(nome,"r")
    linhas=lista.readlines()
    l=1
    for linha in linhas:
        pol=[]
        termo=linha.split(";")
        termo.remove("\n")
        for t in termo:
            mon=t.split(",")
            mono=(float(mon[0]),int(mon[1]))
            pol.append(mono)
        
        print (str(l),"              ",pol)
        l=l+1
    lista.close()

def calculapolinómion(n,x):
    res=0
    for termo in n:
        c, g = termo
        res=res+(c*(x**g))
    return res


def listargrau(nome):
    print("Ordem----Grau--------Polinómio")
    lista=open(nome,"r")
    linhas=lista.readlines()
    l=1
    maior = 0
    for linha in linhas:
        pol=[]
        termo=linha.split(";")
        termo.remove("\n")
        for t in termo:
            mon=t.split(",")
            mono=(float(mon[0]),int(mon[1]))
            pol.append(mono)
        for (c,g) in pol:
            if g > maior:
                maior = g
        print (str(l),"      ",maior,"         ",pol)
        l=l+1
        maior=0
    lista.close()   

def maiorpolinómio(nome):
    print("Polinómio de maior Grau-----Grau-----Ordem")
    lista=open(nome,"r")
    linhas=lista.readlines()
    maior = 0
    ordem = 0
    n=0
    pol=[]
    for linha in linhas:
        pol=[]
        termo=linha.split(";")
        termo.remove("\n")
        ordem=ordem+1
        for t in termo:
            mon=t.split(",")
            c, g= mon
            mono=(float(mon[0]),int(mon[1]))
            #pol.append(mono)
            if int(g) > int(maior):
                maior = g
                o=ordem
                m=n
        n=n+1
    print(lerlista("polinómio.txt")[m],maior,"       ",o)
    lista.close()

def derivada(nome):
    print("Polinómio---Derivada")
    lista=open(nome,"r")
    linhas=lista.readlines()
    for linha in linhas:
        pol=[]
        termo=linha.split(";")
        termo.remove("\n")
        for t in termo:
            mon=t.split(",")
            mono=(float(mon[0]),int(mon[1]))
            pol.append(mono)
        derv=[]
        for c,g in pol:
            if g!=0:
                p=(c/g,g-1)
                derv.append(p)
                p=0
            else:
                p=(0,0)
                derv.append(p)
                p=0
        print(pol,"---",derv)
    lista.close()

def soma(p1,p2):
    print(p1,"+",p2,"=")
    
    registo=[]
    #polinómio(c,g)
    #p1-i;p2-j
    i=0
    j=0
    while i<len(p1) and j<len(p2):
        (c1,g1)=p1[i]        
        (c2,g2)=p2[j]
        if g1==g2:
            p=(c1+c2,g1)
            registo.append(p)
            i=i+1
            j=j+1
        elif g1>g2:
            registo.append((c1,g1)) 
            i=i+1
        else:
            registo.append((c2,g2))
            j=j+1

    while i<len(p1):
        (c1,g1)=p1[i]        
        registo.append((c1,g1)) 
        i=i+1

    while j<len(p2):
        (c2,g2)=p2[j]
        registo.append((c2,g2))
        j=j+1

    print (registo)

import matplotlib.pyplot as plt

def potência(a,b):
    res=1
    while b>0:
        res= a*res
        b=b-1
    return res

def calcula(p,x):
    i=0
    resu=0
    while i<len(p):
        (c1,g1)=p[i]
        resu=resu+(c1*(potência(x,g1)))
        i=i+1
    return resu

def gráfico(p):
    valx=[]
    valy=[]
    x=0
    while x<=10:
        valx.append(x)
        y=calcula(p,x)
        valy.append(y)
        x=x+1

    plt.plot(valx, valy, color = "green")
    plt.xlabel("abssissa")
    plt.ylabel("ordenada")
    plt.title("polinómio")
    plt.show()


def ficheiro(lista,nome):
    file=open(nome, "w")
    for p in listap:
        for polinómio in p:
            c, g = polinómio
            file.write(str(c)+","+str(g)+";")
        file.write("\n")
  
    file.close()




print("MENU \n(1)Criar um polinómio \n(2)Ler lista de Polinómios \n(3)Listar Polinómios \n(4)Calcular valor do Polinómio \n(5)Listar Polinómios e o seu Grau \n(6)Qual o Polinómio de Maior Grau \n(7)Listar Polinómios e suas Derivadas \n(8)Somar dois Polinómios \n(9)Gráfico de um Polinómio \n(10)Gravar Polinómios \n(0)Sair")

opção=(int(input("Que opção deseja?")))

while opção != 0:
    if opção==1:
        criapolinómio()
        opção=(int(input("Que opção deseja?")))
    if opção==2:
        lerlista("polinómio.txt")
        opção=(int(input("Que opção deseja?")))
    if opção==3:
        listar("polinómio.txt")
        opção=(int(input("Que opção deseja?")))
    if opção==4:
        n=int(input("Deseja calcular o valor de que polinómio?"))
        x=int(input("Para que valor de x?"))
        print(calculapolinómion(lerlista("polinómio.txt")[n-1],x))
        opção=(int(input("Que opção deseja?")))
    if opção==5:
        listargrau("polinómio.txt")
        opção=(int(input("Que opção deseja?")))
    if opção==6:
        maiorpolinómio("polinómio.txt")
        opção=(int(input("Que opção deseja?")))
    if opção==7:
        derivada("polinómio.txt")
        opção=(int(input("Que opção deseja?")))
    if opção==8:
        n=int(input("Qual o primeiro polinómio que deseja somar?"))
        m=int(input("Qual o segundo polinómio que deseja somar?"))
        print("Soma dos Polinómios")
        soma(lerlista("polinómio.txt")[n-1],lerlista("polinómio.txt")[m-1])
        opção=(int(input("Que opção deseja?")))
    if opção==9:
        n=int(input("Deseja obter o gráfico de que polinómio?"))
        print("Grafico do polinómio")
        print(gráfico(lerlista("polinómio.txt")[n-1]))
        opção=(int(input("Que opção deseja?")))
    if opção==10:
        listap=[p1,p2,p3,p4,p5,p6]
        ficheiro (listap,"polinómio.txt")
        opção=(int(input("Que opção deseja?")))
print("Programa Encerrado")
# Out:
# MENU
# (1)Criar um polinómio
# (2)Ler lista de Polinómios
# (3)Listar Polinómios
# (4)Calcular valor do Polinómio
# (5)Listar Polinómios e o seu Grau
# (6)Qual o Polinómio de Maior Grau
# (7)Listar Polinómios e suas Derivadas
# (8)Somar dois Polinómios
# (9)Gráfico de um Polinómio
# (10)Gravar Polinómios
# (0)Sair
# Ordem------------Polinómio
# 1                [(1.0, 7), (-3.7, 4), (5.0, 3), (-88.0, 0)]
# 2                [(2.0, 2), (17.0, 0)]
# 3                [(7.0, 4), (6.0, 3), (-1.0, 2), (43.0, 0)]
# 4                [(1.0, 4)]
# 5                [(1.0, 2)]
# 6                [(1.0, 3)]
# Polinómio de maior Grau-----Grau-----Ordem
# [(1.0, 7), (-3.7, 4), (5.0, 3), (-88.0, 0)] 7         1
# Soma dos Polinómios
# [(1.0, 7), (-3.7, 4), (5.0, 3), (-88.0, 0)] + [(2.0, 2), (17.0, 0)] =
# [(1.0, 7), (-3.7, 4), (5.0, 3), (2.0, 2), (-71.0, 0)]
# Programa Encerrado
